% %%
a = 0; b = 2; n = 4;
precision = 0.0001;
u = a:precision:b;
r_u = (u-a)./(b-a);
[x_p, y_p] = ginput(n+1);
p_x = zeros(1, length(u));
p_y = zeros(1, length(u));
for i = 1:length(u)
    [t_x, t_y] = de_casteljau(n, x_p, y_p, r_u(i));
    p_x(i) = t_x(n+1, n+1); 
    p_y(i) = t_y(n+1, n+1);
end
